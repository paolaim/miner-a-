# %% [markdown]
# <a href="https://colab.research.google.com/github/paolaim/mineria-datos/blob/gh-pages/Ej_Limpieza_Equipo7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##  **EQUIPO 7:**
#
#   1731502 PAOLA IBARRA MEDRANO
#
#   1799361 MARISSA ALEIDA LUCAS BELMAR
#
#   1744128 REYNA YARELLI BLANCO GONZALEZ
#
#   1723446 AARON EMMANUEL GARZA ALVAREZ

# %% [markdown]
# **world happines report up to 2020**
#
# Fuente: https://www.kaggle.com/mathurinache/world-happiness-report?select=2020.csv
#
#   **Temperature change**
#
#   Fuente: *https*://www.kaggle.com/sevgisarac/temperature-change

# %% [markdown]
#  **DATOS SIN MANIPULACION**
#
#   WORLD HAPINESS REPORT UP TO 2020

# %%
import pandas as pd 
import numpy as np

# %%
tb = pd.read_csv ('/content/2015_2019_2020.csv')

# %%
tb.shape
# Out:
# (158, 43)

# %%
tb.head(153)
# Out:
#           Country  ... Dystopia + residual
# 0     Switzerland  ...            2.762835
# 1         Iceland  ...            2.432741
# 2         Denmark  ...            2.350267
# 3          Norway  ...            2.460688
# 4          Canada  ...            2.168266
# ..            ...  ...                 ...
# 148          Chad  ...            2.860198
# 149        Guinea  ...            0.548445
# 150   Ivory Coast  ...            0.841031
# 151  Burkina Faso  ...            1.378751
# 152   Afghanistan  ...            1.507236
#
# [153 rows x 43 columns]

# %%
tb.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual', 'Unnamed: 12', 'Overall rank',
#        'Country or region', 'Score', 'GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices',
#        'Generosity.1', 'Perceptions of corruption', 'Unnamed: 22',
#        'Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support.1',
#        'Healthy life expectancy.1', 'Freedom to make life choices.1',
#        'Generosity.2', 'Perceptions of corruption.1',
#        'Ladder score in Dystopia', 'Explained by: Log GDP per capita',
#        'Explained by: Social support', 'Explained by: Healthy life expectancy',
# ...

# %%
tb.dtypes
# Out:
# Country                                        object
# Region                                         object
# Happiness Rank                                  int64
# Happiness Score                               float64
# Standard Error                                float64
# Economy (GDP per Capita)                      float64
# Family                                        float64
# Health (Life Expectancy)                      float64
# Freedom                                       float64
# Trust (Government Corruption)                 float64
# Generosity                                    float64
# Dystopia Residual                             float64
# Unnamed: 12                                   float64
# Overall rank                                  float64
# Country or region                              object
# Score                                         float64
# GDP per capita                                float64
# ...

# %% [markdown]
# **Explicación:**
#
# La base de datos nos puede ayudar mucho en cuestiones laborales, como los factores que los afectan para la toma de decisiones, y decidimos quedarnos con las columnas de los datos  más relevantes de las razones por las cuales influyen en que una persona es feliz, y en conjunto, una sociedad.
# Y en cuanto a las filas, solo decidimos quedarnos con los paises más importantes, en este caso, el que se posicionaba en el número 1 al inicio de la encuesta de la base de datos y quien ahora esté en el número 1 en los años 2019 a 2020; México como nuestro país, viendo los factores que lo afectan; EUA como un país importante en todo el mundo y vecino nuestro, y otro país de America latina y vecino, como Guatemala.

# %%
tb1 = pd.read_csv ('/content/2015_2019_2020_limpia.csv')

# %%
tb1.shape
# Out:
# (4, 18)

# %% [markdown]
# **BASE DE DATOS LIMPIA**

# %%
tb1.head(153)
# Out:
#          Country  ...  Perceptions of corruption.1
# 0    Switzerland  ...                     0.195445
# 1         Mexico  ...                     0.699715
# 2  United States  ...                     0.806822
# 3      Guatemala  ...                     0.783237
#
# [4 rows x 18 columns]

# %%
tb1.corr()
# Out:
#                                Happiness Rank  ...  Perceptions of corruption.1
# Happiness Rank                       1.000000  ...                     0.682570
# Happiness Score                     -0.999227  ...                    -0.661368
# Economy (GDP per Capita)            -0.863832  ...                    -0.495396
# Trust (Government Corruption)       -0.846387  ...                    -0.965860
# Dystopia Residual                    0.035920  ...                     0.269170
# Unnamed: 6                                NaN  ...                          NaN
# Overall rank                         0.813711  ...                     0.980068
# Score                               -0.806214  ...                    -0.978969
# GDP per capita                      -0.850123  ...                    -0.528621
# Perceptions of corruption           -0.697767  ...                    -0.999777
# Unnamed: 12                               NaN  ...                          NaN
# ...

# %% [markdown]
# **DATOS SIN MANIPULACIÓN**
#
# TEMPERATURE CHANGE

# %%
import pandas as pd 
import numpy as np

# %%
tc1 = pd.read_excel('/content/Environment_Temperature_change_E_All_Data_NOFLAG.xlsx')

# %%
tc1.shape
# Out:
# (9656, 66)

# %%
tc1.head(153)
# Out:
#      Area Code         Area  Months Code     Months  ...  Y2016  Y2017  Y2018  Y2019
# 0            2  Afghanistan         7001    January  ...  3.416  1.201  1.996  2.951
# 1            2  Afghanistan         7001    January  ...  1.950  1.950  1.950  1.950
# 2            2  Afghanistan         7002   February  ...  2.251 -0.323  2.705  0.086
# 3            2  Afghanistan         7002   February  ...  2.597  2.597  2.597  2.597
# 4            2  Afghanistan         7003      March  ...  2.296  0.834  4.418  0.234
# ..         ...          ...          ...        ...  ...    ...    ...    ...    ...
# 148          6      Andorra         7007       July  ...  1.972  1.947  3.244  3.482
# 149          6      Andorra         7007       July  ...  1.060  1.060  1.060  1.060
# 150          6      Andorra         7008     August  ...  2.368  2.602  3.278  2.844
# 151          6      Andorra         7008     August  ...  1.022  1.022  1.022  1.022
# ...

# %%
tc1.columns
# Out:
# Index(['Area Code', 'Area', 'Months Code', 'Months', 'Element Code', 'Element',
#        'Unit', 'Y1961', 'Y1962', 'Y1963', 'Y1964', 'Y1965', 'Y1966', 'Y1967',
#        'Y1968', 'Y1969', 'Y1970', 'Y1971', 'Y1972', 'Y1973', 'Y1974', 'Y1975',
#        'Y1976', 'Y1977', 'Y1978', 'Y1979', 'Y1980', 'Y1981', 'Y1982', 'Y1983',
#        'Y1984', 'Y1985', 'Y1986', 'Y1987', 'Y1988', 'Y1989', 'Y1990', 'Y1991',
#        'Y1992', 'Y1993', 'Y1994', 'Y1995', 'Y1996', 'Y1997', 'Y1998', 'Y1999',
#        'Y2000', 'Y2001', 'Y2002', 'Y2003', 'Y2004', 'Y2005', 'Y2006', 'Y2007',
#        'Y2008', 'Y2009', 'Y2010', 'Y2011', 'Y2012', 'Y2013', 'Y2014', 'Y2015',
#        'Y2016', 'Y2017', 'Y2018', 'Y2019'],
#       dtype='object')

# %%
tc1.dtypes
# Out:
# Area Code         int64
# Area             object
# Months Code       int64
# Months           object
# Element Code      int64
#                  ...
# Y2015           float64
# Y2016           float64
# Y2017           float64
# Y2018           float64
# Y2019           float64
# Length: 66, dtype: object

# %% [markdown]
# **Explicación**
#
# En la temperatura se sacó un promedio de los datos entre 2 años para tener menos agrupaciones.
#
# Se dejó el dato de la desviación estándar, porque nos ayuda a saber la dispersión que existe dentro de un conjunto de datos.
#
# Decidimos utilizar esta base de datos, ya que de esta manera podremos informar a la población en general y/o empresas del cambio climátio que está sufriendo hoy en día nuestro planeta y así pensar en una idea para detener este acelerador.

# %%
tc2 = pd.read_excel('/content/Cambio_de_Temperatura.xlsx')

# %%
tc2.shape
# Out:
# (9656, 36)

# %%
tc2.head(153)
# Out:
#      Area Code         Area  Months Code  ... 2015-2016  2017-2018   2019
# 0            2  Afghanistan         7001  ...    2.6795     1.5985  2.951
# 1            2  Afghanistan         7001  ...    1.9500     1.9500  1.950
# 2            2  Afghanistan         7002  ...    2.4750     1.1910  0.086
# 3            2  Afghanistan         7002  ...    2.5970     2.5970  2.597
# 4            2  Afghanistan         7003  ...    0.8995     2.6260  0.234
# ..         ...          ...          ...  ...       ...        ...    ...
# 148          6      Andorra         7007  ...    2.8670     2.5955  3.482
# 149          6      Andorra         7007  ...    1.0600     1.0600  1.060
# 150          6      Andorra         7008  ...    2.1605     2.9400  2.844
# 151          6      Andorra         7008  ...    1.0220     1.0220  1.022
# 152          6      Andorra         7009  ...    1.2590     1.3195  1.951
#
# [153 rows x 36 columns]

# %%
tc2.corr()
# Out:
#                  Area Code   Months Code  ...  2017-2018      2019
# Area Code     1.000000e+00  1.303340e-17  ...   0.019126 -0.048747
# Months Code   1.303340e-17  1.000000e+00  ...  -0.071941 -0.067192
# Element Code  0.000000e+00  0.000000e+00  ...   0.481453  0.473978
# 1961 - 1962  -2.158106e-02 -1.061400e-01  ...   0.078193  0.002579
# 1963 -1964   -2.507843e-02 -7.700822e-02  ...   0.001973 -0.158558
# 1965 - 1966  -2.576649e-02 -1.055863e-01  ...   0.005841 -0.039568
# 1967 - 1968  -2.481035e-02 -5.824273e-02  ...  -0.034575 -0.076973
# 1969 - 1970  -3.137393e-02 -1.106385e-01  ...   0.002200 -0.196283
# 1971 -1972   -2.330948e-02 -8.833662e-02  ...   0.017975 -0.069198
# 1973 -1974   -1.279133e-02 -1.448925e-01  ...   0.074660  0.003915
# 1975 -1976   -1.823881e-02 -9.916916e-02  ...   0.032544 -0.028621
# 1977-1978    -2.234357e-02 -1.165751e-01  ...   0.050415 -0.080668
# 1979-1980    -6.129799e-03 -1.038163e-01  ...   0.034148 -0.007792
# ...
